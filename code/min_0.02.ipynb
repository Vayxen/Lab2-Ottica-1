# %%
import re
import os
from os import path

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from lab_tools import graph, lab_round

# %matplotlib widget

width = 469.75502 # To get the page width insert "\the\textwidth" in your LaTeX document
here_path = path.abspath('') # path.dirname(__file__)
graph_path = path.join(here_path, "../images/")
data_path = path.join(here_path, "../data/")

mpl.rcParams.update({
    # Show minor ticks
    "ytick.minor.visible": True,
    "xtick.minor.visible": True,
    # Use LaTeX to write all text
    "text.usetex": True,
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 11,
    "font.size": 11,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    # High resolution .png
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    # Default image size
    "figure.figsize": graph.size(width),
})

# %%
wave_length = 650 / 10**9

slits = [0.02, 0.04, 0.08]
sensors = [0.5, 1.0, 1.5]

slit_name = 0.02
slit = slit_name / 10**3
slit_pos = 4 / 10**2

sensor_name = 1.5
sensor = sensor_name / 10**3
sensor_pos = 102.5 / 10**2

distance = sensor_pos - slit_pos

# %%
files_15 = [
    file
    for file in os.listdir(path.join(data_path, "raw"))
    if re.search(f"\\w+ {slit_name:.2f} {1.5:.1f}.tsv", file)
]

dfs_15 = [
    pd.read_csv(
        path.join(data_path, "raw", file),
        sep='\t',
        engine='python',
    )
    for file in files_15
]

files_10 = [
    file
    for file in os.listdir(path.join(data_path, "raw"))
    if re.search(f"\\w+ {slit_name:.2f} {1.0:.1f}", file)
]

dfs_10 = [
    pd.read_csv(
        path.join(data_path, "raw", file),
        sep='\t',
        engine='python',
    )
    for file in files_10
]

files_05 = [
    file
    for file in os.listdir(path.join(data_path, "raw"))
    if re.search(f"\\w+ {slit_name:.2f} {0.5:.1f}.tsv", file)
]

dfs_05 = [
    pd.read_csv(
        path.join(data_path, "raw", file),
        sep='\t',
        engine='python',
    )
    for file in files_05
]


for df in dfs_15 + dfs_10 + dfs_05:
    df.y -= df.y.min()
    df['dI'] = 0.1 * df.I
    # df.I -= df.I.min()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Documenti\Documenti\Università\Triennale\Anno 2\Laboratorio II\2 Semestre\Esperienze\Diffrazione\code\min_0.02.ipynb Cell 3' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=0'>1</a> files_15 = [
#       <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=1'>2</a>     file
# ----> <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=2'>3</a>     for file in os.listdir(path.join(data_path, "raw"))
#       <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=3'>4</a>     if re.search(f"\\w+ {slit_name:.2f} {1.5:.1f}.tsv", file)
#       <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=4'>5</a> ]
#       <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=6'>7</a> dfs_15 = [
#       <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=7'>8</a>     pd.read_csv(
#       <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=8'>9</a>         path.join(data_path, "raw", file),
#    (...)
#      <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=12'>13</a>     for file in files_15
#      <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=13'>14</a> ]
#      <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=15'>16</a> files_10 = [
#      <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=16'>17</a>     file
#      <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=17'>18</a>     for file in os.listdir(path.join(data_path, "raw"))
#      <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=18'>19</a>     if re.search(f"\\w+ {slit_name:.2f} {1.0:.1f}", file)
#      <a href='vscode-notebook-cell:/d%3A/Documenti/Documenti/Universit%C3%A0/Triennale/Anno%202/Laboratorio%20II/2%20Semestre/Esperienze/Diffrazione/code/min_0.02.ipynb#ch0000002?line=19'>20</a> ]
#
# FileNotFoundError: [WinError 3] Impossibile trovare il percorso specificato: 'd:\\Documenti\\Documenti\\Università\\Triennale\\Anno 2\\Laboratorio II\\2 Semestre\\Esperienze\\Diffrazione\\code\\../data/raw'

# %%
fig, ax = plt.subplots(1, 1)
fig.suptitle(f"Scatter con fenditura a {slit_name} mm", fontsize=11)

for i, df in enumerate(dfs_15):
    ax.scatter(df.y, df.I, s=1, alpha = 0.5, label=f"Set {i+1} a 1.5 mm")
for df in dfs_10:
    ax.scatter(df.y, df.I, s=1, alpha = 0.5, label=f"Set a 1.0 mm")
for df in dfs_05:
    ax.scatter(df.y, df.I, s=1, alpha = 0.5, label=f"Set a 0.5 mm")


xlim = ax.get_xlim()
ax.plot(xlim, [0, 0], c="black")

ylim = ax.get_ylim()

min_list = [
    (1.92, 2.26),
    (4.86, 5.16),
    (11.05, 11.33),
    (13.94, 14.21),
]

ax.fill_betweenx(ylim, [1.92]*2, [2.26]*2, alpha = 0.5, color="gold", label="Minimi") # 2.09 +/- 0.17
ax.fill_betweenx(ylim, [4.86]*2, [5.16]*2, alpha = 0.5, color="gold") # 5.01 +/- 0.15
ax.fill_betweenx(ylim, [11.05]*2, [11.33]*2, alpha = 0.5, color="gold") # 11.19 +/- 0.14
ax.fill_betweenx(ylim, [13.94]*2, [14.21]*2, alpha = 0.5, color="gold") # 14.08 +/- 0.14

ax.set_xlabel("$x \; (cm)$")
ax.set_ylabel("$I$")

ax.legend()
ax.set_xlim(xlim)
ax.set_ylim(-0.025, 0.15)

fig.savefig(path.join(graph_path, f"min_{slit_name}.png"))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Valori dei minimi sono
#
# - 2.09 +/- 0.17
# - 5.01 +/- 0.15
# - 11.19 +/- 0.14
# - 14.08 +/- 0.14
#
# Le distanze sono
#
# - 2.92 +/- 0.32
# - Ignoro 6.18 / 2 = 3.09 +/- 0.15
# - 2.89 +/- 0.28
#
# $\frac{\lambda L}{a} = (2.9 \pm 0.3) cm$

# %%
wave_length * distance / 2.9 * 10**5
# Out:
# 0.022077586206896548

# %% [markdown]
# 0.022 +/- 0.002
